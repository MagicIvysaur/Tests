# %% [markdown]
# <a href="https://colab.research.google.com/github/MagicIvysaur/Tests/blob/main/Hangman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import json
from IPython.display import clear_output
from google.colab import files

turno = 0
secretcounter = 0
wincounter = 0
numbersec = 0

palabrasecreta = []
diccionario = ['crema', 'explosión', 'navaja', 'lápiz', 'embarcación', 'ventana', 'universidad', 'llaves', 'papá', 'escuela', 'codo', 'mapa', 'lima', 'edificio', 'hojas', 'granizo', 'mano', 'música', 'habitación', 'abuelo', 'templo', 'plato', 'botella', 'casa', 'planeta', 'metal', 'mono', 'petróleo', 'debate', 'ruido', 'herramienta', 'anteojos', 'living', 'zapato', 'ojo', 'diente', 'buzo', 'puerta', 'ensalada', 'candidato', 'diarios', 'hierro', 'barco', 'tecla', 'departamento', 'hipopótamo', 'árbol', 'discurso', 'rúcula', 'lentejas', 'reloj', 'desodorante', 'montañas', 'moño', 'partido', 'fiesta', 'café', 'guitarra', 'martillo', 'lapicero', 'letra', 'librería', 'rueda', 'camisa', 'sillón', 'teclado', 'pantalla', 'tenedor', 'agua', 'cohete', 'césped', 'parlante', 'pestaña', 'monitor', 'hombre', 'velero', 'palo', 'lentes', 'nube', 'castillo', 'libro', 'televisor', 'teléfono', 'camisa', 'percha', 'anillo', 'pared', 'cartas', 'impresora', 'luces', 'bomba', 'corbata', 'planta', 'oficina', 'tío', 'pradera', 'deporte', 'fotografía', 'refugio', 'carne', 'humedad', 'celular', 'sofá', 'mesada', 'auto', 'famoso', 'piso', 'diputado', 'candado', 'computadora', 'cuadro', 'teatro', 'bala', 'estrella', 'plástico', 'libros', 'aluminio', 'aguja', 'sonido', 'perro', 'pelo', 'felicidad', 'servilleta', 'sol', 'estadística', 'mensaje', 'rey', 'presidencia', 'colegio', 'lámpara', 'flor', 'tornillo', 'abuela', 'satélite', 'bolígrafo', 'gobierno', 'enano', 'persona', 'guantes', 'proyector', 'muela', 'remate', 'cuaderno', 'taladro', 'chocolate', 'caramelos', 'angustia', 'lluvia', 'periódico', 'persiana', 'silla', 'zoológico', 'recipiente', 'ave', 'pantalón', 'nieve', 'pistola', 'tristeza', 'cama', 'campera', 'cinturón', 'madera', 'maletín', 'cuchillo', 'luz', 'radio', 'calor', 'auriculares']
intentolista = []
listaescondida = []
listareveal = []
dificultadlista = ["Libre", "Fácil", "Facil", "Intermedio", "Dificil"]

def hangman():
    
    def namereq():
        global name
        name = input("Hola! Introduzca su nombre, por favor:")
        clear_output(wait=True)
        if name.isalpha():

            print("Hola, " + name + "!")

        else: 
            print("Por favor introduzca solo letras." )
            print("-------------------")
            namereq()

    time.sleep(1)
    namereq()
    
    def difficultyset():
        global turno
        
        difficulty = input("Por favor elija un nivel de dificultad:" + "\n"
                        "\n"
                           "Libre - Los fallos se cuentan, pero no hay penalización." + "\n"
                            "Fácil - 12 fallos permitidos." + "\n"
                              "Intermedio - 5 fallos permitidios." + "\n"
                                  "Dificil - 3 fallos permitidos." + "\n")
        clear_output(wait=True)
        print("-------------------")

        if difficulty not in dificultadlista:

            print("Por favor introduzca un nivel de dificultad de la lista:" + "\n"
                 "Libre, Fácil, Intermedio, Dificil")
            print("-------------------")
            difficultyset()

        clear_output(wait=True)

        while difficulty in dificultadlista:           

            if difficulty == "Libre":
                import math
                turno = math.inf
                return turno, print("Nivel de dificultad seleccionado: " + str(difficulty) + "\n"
                 "Tiene " + str(turno) + " turnos!")
            elif difficulty == "Fácil" or difficulty =="Facil":
                turno = turno + 12
                return turno, print("Nivel de dificultad seleccionado: " + str(difficulty) + "\n"
                 "Tiene " + str(turno) + " turnos!")
            elif difficulty == "Intermedio":
                turno = turno + 5
                return turno, print("Nivel de dificultad seleccionado: " + str(difficulty) + "\n"
                 "Tiene " + str(turno) + " turnos!")
            elif difficulty == "Dificil":
                turno = turno + 3
                return turno, print("Nivel de dificultad seleccionado: " + str(difficulty) + "\n"
                 "Tiene " + str(turno) + " turnos!")
        print(turno)
    
    difficultyset()

    def escogerpalabra():
      global palabrasecreta
      global numbersec
      global diccionario
      
      numbersec = input("Por favor escoja el largo de la palabra a adivinar con un número: ")
      numbersec = int(numbersec)

      palabrasecreta = [word for word in diccionario if len(word) == numbersec]
      return random.choice(palabrasecreta)

    def setuppalabra():
        global palabrasecreta
        global listareveal
        global palabraesc
        global listapalabrasec
        palabrasecreta = escogerpalabra()
        listapalabrasec = list(palabrasecreta)
        
        for char in listapalabrasec:
       
          listaescondida.append(" _ ")
                
        listareveal = listareveal + listaescondida
        print("La palabra secreta es: " + str(listaescondida))

        return listapalabrasec
        

    setuppalabra()

    def secretsetup():
      global palabrasecreta
      global secretcounter
      for elem in palabrasecreta:
            for char in elem:
              secretcounter = secretcounter + 1

    secretsetup()

    def adivinar():
        global intentolista
        global turno
        global listapalabrasec
        global palabrasecreta
        global secretcounter
        global wincounter
        global listaescondida
        global listareveal
        global name
        
        print("Adivine una letra!")
        print("Letras adivinadas " + str(listareveal))
        letra = input() 

        guesscheck = str(palabrasecreta).count(letra)
        wincounter = wincounter + guesscheck

        if wincounter == secretcounter:

          resultados = ["Jugador: ", "Palabra secreta: ", "Turnos restantes: "]
          with open("score_file.json", "w") as archivo:
            json.dump(resultados, archivo)
          
          print("Felicidades, ganó!" + "\n"
                "La palabra secreta era " + str(palabrasecreta) + "\n"
                  "Quiere jugar de nuevo? Y/N: " + "\n")
          
          playagain = input()
          if playagain == "Y" or playagain == "y":
            hangman()
          elif playagain == "N" or playagain == "n":
            print("Hasta luego!")
            sys.exit(0)
        if letra in intentolista:
            print("Esta letra ya se usó! Intente otra letra.")
            adivinar()

        else:
            intentolista.append(letra)
            if letra in str(palabrasecreta):

              for i in range(len(listapalabrasec)):
                if letra == listapalabrasec[i]:
                  indice = i
                  listareveal[indice] = letra
                  print(listareveal)
              
              print("Correcto!")
              if turno > 0:
                  print("Le quedan " + str(turno) + " intentos!")
                  clear_output(wait=True)
                  time.sleep(1)
                  adivinar()
              elif turno == 0:
                print(listareveal)
                print("Lo siento no hay más intentos :(" + "\n"
                      "La palabra secreta era " + str(palabrasecreta) + "\n"
                        "Quiere jugar de nuevo? Y/N: " + "\n")
                playagain = input()
                if playagain == "Y" or playagain == "y":
                  hangman()
                elif playagain == "N" or playagain == "n":
                  print("Hasta luego!")
                  sys.exit(0)
                  

            elif letra not in str(palabrasecreta):
              turno = turno - 1
              print("Buen intento, trate otra vez!")
              print(listareveal)
              if turno > 0:
                    print("Le quedan " + str(turno) + " intentos!")
                    clear_output(wait=True)
                    adivinar()
              elif turno == 0:
                print(listareveal)
                print("Lo siento no hay más intentos :(" + "\n"
                      "La palabra secreta era: " + "'" + str(palabrasecreta) + "'" "\n"
                        "Quiere jugar de nuevo? Y/N: " + "\n")
                playagain = input()
                if playagain == "Y" or playagain == "y": 
                  hangman()
                elif playagain == "N" or playagain == "n":
                  print("Hasta luego!")
                  sys.exit(0)
                  
                
            
        print(intentolista)
            
    adivinar()
  


hangman()
# Out:
# -------------------
# Por favor introduzca un nivel de dificultad de la lista:
# Libre, Fácil, Intermedio, Dificil
# -------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     618         """
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

numbersec = 0
def escogerpalabra():
  numbersec = input("Por favor escoja el largo de la palabra a adivinar con un número: ")
  numbersec = int(numbersec)
  with open('/content/drive/My Drive/palabras.txt') as dicc:
    palabraesc = [word for word in dicc if len(word) == numbersec]
    return random.choice(palabraesc)
    
escogerpalabra()
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     565         """
# --> 566         parts = [self.recv(flags, copy=copy, track=track)]
#     567         # have first part already, only loop while more to receive
#
# ...

# %%
def setuppalabra():
  global palabrasecretatest
  global listarevealtest
  global palabraesc
  global listapalabrasectest
  listarevealtest = []
  listaescondidatest = []
  palabrasecretatest = "carro"
  listapalabrasectest = list(palabrasecretatest)
  
  for char in listapalabrasectest:
    listaescondidatest.append(" _ ")
          
  listarevealtest = listarevealtest + listaescondidatest
  print("La palabra secreta es: " + str(listaescondidatest))
  return listaescondidatest

setuppalabra()

def adivinar():
    global intentolista
    global turno
    global listapalabrasec
    global palabrasecretatest
    global secretcounter
    global wincounter
    global listaescondidatest
    global listareveal
    global listapalabrasectest

    intentolistatest = []
    turno = 10
    
    print("Adivine una letra!")
    
    letra = input() 
      
    if letra in intentolistatest:
        print("Esta letra ya se usó! Intente otra letra.")
        adivinar()

    else:
        intentolistatest.append(letra)
        if letra in str(palabrasecretatest):

          for item in range(len(listapalabrasectest)):
            if letra == listapalabrasectest[item]:
                listaescondidatest[item] = letra

          print(str(listaescondidatest))
          print("Correcto!")
          if turno > 0:
              print("Le quedan " + str(turno) + " intentos!")
              adivinar()
          elif turno == 0:
            print("Lo siento no hay más intentos :(" + "\n"
                  "La palabra secreta era " + str(palabrasecreta) + "\n"
                    "Quiere jugar de nuevo? Y/N: " + "\n")
            playagain = input()
            if playagain == "Y" or playagain == "y":
              hangman()
            elif playagain == "N" or playagain == "n":
              print("Hasta luego!")
              

        elif letra not in str(palabrasecretatest):
          turno = turno - 1
          print("Buen intento, trate otra vez!")
          if turno > 0:
                print("Le quedan " + str(turno) + " intentos!")
                adivinar()
          elif turno == 0:
            print("Lo siento no hay más intentos :(" + "\n"
                  "La palabra secreta era " + str(palabrasecretatest) + "\n"
                    "Quiere jugar de nuevo? Y/N: " + "\n")
            playagain = input()
            if playagain == "Y" or playagain == "y": 
              hangman()
            elif playagain == "N" or playagain == "n":
              print("Hasta luego!")
              
            
        
    print(intentolista)
        
adivinar()

# %%
import requests

calendarreq = requests.get(https://calendarific.com/api/v2/holidays?api_key=fb5fe73b71a51f8115910071132895f8bad223a2&country=cr&year=2021)
calendarreq
# Out:
#   File "<ipython-input-1-70ac6e034d47>", line 3
#     calendarreq = requests.get(https://calendarific.com/api/v2/holidays?api_key=fb5fe73b71a51f8115910071132895f8bad223a2&country=cr&year=2021)
#                                     ^
# SyntaxError: invalid syntax
